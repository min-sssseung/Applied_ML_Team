# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/kmk45/OneDrive/바탕 화면/AML/Main/Financial/ESG_type_changed.csv')
df.tail().iloc[:, :-5]

# 자산총계 = 부채 총계 + 자본 총계 (단위 같을 것)
# 영업이익은 사용 x => 영업활동 현금 흐름

# 문제는 영업활동 현금흐름 vs 자산총계
# Out:
#          회사명  corp_code  stock_code    연도 ESG          자산총계          부채총계  \
# 2364     아난티     161781       25980  2020   D  1.143676e+12  7.769593e+11
# 2365     상상인     306162       38540  2020   D  3.605932e+12  2.914391e+12
# 2366      씨젠     788773       96530  2020   D  1.094575e+12  4.481687e+11
# 2367  덕산네오룩스    1061558      213420  2020   D  2.209129e+11  2.815705e+10
# 2368    로보스타     536523       90360  2020   C  1.348000e+10  5.920071e+10
#
#               영업이익    법인세차감전 순이익    intangible  ratio  pre_ratio  out_exec  \
# 2364 -3.172375e+10 -4.974210e+10  4.019670e+09    NaN        NaN       0.0
# 2365  9.405292e+10  8.769622e+10  5.470796e+10    NaN        NaN       0.0
# 2366  6.761897e+11  6.691388e+11  6.713725e+09    7.8        NaN       0.0
# 2367  4.011248e+10  3.776133e+10  3.657436e+10    NaN        NaN       0.0
# 2368 -1.131563e+10 -1.166818e+10  1.980430e+09    NaN        NaN       0.0
#
#      share_holder  정규직 수  비정규직 수
# 2364        32.33  440.0    30.0
# ...
