# %%
import pandas as pd

# %%
df = pd.read_csv('./merged_finance_dataframe.csv', encoding='utf-8') # 민승이 데이터
df.head()
# Out:
#      종목코드      최고가      최저가 수익률(1달) 수익률(3달) 수익률(6달) 수익률(1년)        발행주식수  \
# 0  265520   22,750   16,300   -2.92  -14.84  -18.83   -4.37   15,281,421
# 1  211270   25,800    8,800  -21.97   -3.41  -36.60  +25.89   15,082,304
# 2  282330  213,000  130,900   -1.70  -17.35  -22.13  -24.67   17,283,906
# 3  126600    8,545    3,805  -12.07  -23.29  -48.25  -12.47   54,033,275
# 4  138930    7,440    6,170   +0.58   +1.47   +4.87   +6.99  322,088,438
#
#      시가총액                 업종명   액면가            자본금
# 0   2,543       특수 목적용 기계 제조업   500     7640710500
# 1   1,709    항공기,우주선 및 부품 제조업   500     7541152000
# 2  23,955              종합 소매업  1000    17283906000
# 3   2,126  합성고무 및 플라스틱 물질 제조업   500    27016637500
# 4  22,192              기타 금융업  5000  1629676230000

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214 entries, 0 to 1213
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종목코드     1214 non-null   int64
#  1   최고가      1214 non-null   object
#  2   최저가      1214 non-null   object
#  3   수익률(1달)  1214 non-null   object
#  4   수익률(3달)  1214 non-null   object
#  5   수익률(6달)  1214 non-null   object
#  6   수익률(1년)  1214 non-null   object
#  7   발행주식수    1214 non-null   object
#  8   시가총액     1214 non-null   object
#  9   업종명      1214 non-null   object
#  10  액면가      1214 non-null   object
#  11  자본금      1214 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 113.9+ KB
# None
#                 종목코드           자본금
# count    1214.000000  1.214000e+03
# mean   272035.683690  2.411150e+10
# std    136274.636268  1.585997e+11
# min    100030.000000  0.000000e+00
# 25%    175645.000000  3.008800e+09
# 50%    254325.000000  5.671570e+09
# ...
